# %% [markdown]
# Make sure you type in your **NAME** and fill in any place that says `YOUR CODE HERE` or `YOUR ANSWER HERE`. After you've typed in your answer delete (or comment out) the line that says ```raise NotImplementedError()```.
#
# **Before you turn this assignment in, make sure everything runs as expected. From the menubar, select Kernel $\rightarrow$ Restart Kernel and Run All Cells to check.**

# %%
NAME = ""

# %% [markdown]
# ---

# %% [markdown]
# # Python Skills Check
# ---
#
# *The purpose of this notebook is to check and refresh your Python coding skills. Work your way through as much of this notebook as you can in the next 10 minutes and submit through Canvas. This is only being checked for completion. Finish this without looking online for help. Feel free to ask for hints from your instructor.*
#
# ***Make sure to assign your answers to the correct variables for questions 1 and 2.***

# %% [markdown]
# ### 1. Translating math to code and variable assignment.
#
# Given parabolic flight, the height $y$ of a ball is given by the equation:
# $$ y = x\tan(\theta) - \left[ \frac{1}{2 v_{0}^2} \right] \left[\frac{g x^{2}}{cos(\theta)^{2}} \right] + y_{0} $$
#
# <!-- $$ y = x\tan(\theta) - \frac{1}{2 v_{0}^2} \cdot \frac{g x^{2}}{cos(\theta)^{2}}  + y_{0} $$ -->
#
#
# where $x$ is a horizontal coordinate (meters), $g$ is the acceleration of gravity (meters per second per second), $v_{0}$ is the initial velocity (meters per second) at an angle $\theta$ (radians) with the x-axis, and $y_0$ is the initial position of the ball (meters).
#
# **Translate the equation above into Python code in order to compute the vertical height $y$ of a ball.**

# %% [markdown]
# **Test your program with the values given in the example below. Assign your answer to the variable `answer_1`.**
# ```
# g (m/s/s): 9.8
# for v0 (m/s): 6.789
# theta (rad): 0.123
# x (m): 4.5
# y0 (m): 5.4

# %%
# Run this line to import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from math import tan, cos

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# Leave this blank

# %% [markdown]
# ---
# ### 2. Compute a dot product using a `for` loop.
# The dot product is defined as:
#
# $$\vec{a} \cdot \vec{b} = a_1 \times b_1 + a_2 \times b_2 + ... + a_n \times b_n = \sum_{i=1}^{n} a_i b_i$$
#
# where $a_i$ and $b_i$ are the components of vectors $\vec{a}$ and $\vec{b}$ in the ith index (position), respectively. [Vectors are just ordered lists of values, like Python lists, except vectors must contain numeric values. This $\sum_{i=1}^{n}$ symbol means you are summing each pair of products, $a_i b_i$.]
#
# **Given the following two lists, compute a dot product using a for loop. Assign your answer to the variable `answer_2`.**

# %%
# Run this cell
a = [10, 15, 99, 2, 3, -5, -9, 10, 5, 20]
b = [1, -5, 0, 2, 10, 4, -3, 2, 76, -8]

# %%
# YOUR CODE HERE
raise NotImplementedError()

# %%
# Leave this blank

# %% [markdown]
# ---
# ### [BONUS EXTRA] Generate a multi-line plot with `Matplotlib`.
# We have a 1D array $x$ with values $[1,2,3,4,5]$. We also have 1D arrays $y1$ with values $[1,2,3,4,4]$, $y2$ with $[1,5,6,8,10]$, and $y3$ with $[5,4,2,1,1]$. Generate a multi-line plot using squares (markersize 6.0) connected with solid lines (linewidth 1.0). Label the axes as shown, and set axis limits and axis ticks as shown. Add a legend as shown. The $y1$ colour is blue, the $y2$ colour is red, and the $y3$ colour is magenta. Your figure should look like the one below.
#
# Some of the parameters you will want to adjust:
# - *color, markersize, marker, linewidth, label, xticks, xlabel, etc.*
#
# **Hint: You can copy the lines below to get a good start. Replace the ellipses (...) with your code.**
# ```python
# fig, ax = plt.subplots()
# ax.plot(...)
# ```

# %% [markdown]
# <img src="../../images/A7-multiline-plot.jpeg" width=600>

# %%
# Run this cell
x = np.linspace(1, 5, num=5)
y1 = np.array([1, 2, 3, 4, 4])
y2 = np.array([1, 5, 6, 8, 10])
y3 = np.array([5, 4, 2, 1, 1])

# %%
# YOUR CODE HERE
raise NotImplementedError()
